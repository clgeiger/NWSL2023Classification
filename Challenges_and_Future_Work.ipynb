# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.feature_selection import mutual_info_classif, f_classif, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# For the data ascquisition, I manually entered all of the "1st half" statistics as well as the end result for every NWSL game from the 2023 season. These numbers were gathered from this website: https://www.fotmob.com/leagues/9134/overview/nwsl
#
# Each game is stored as two observations, one for each team. So for example is the game is a win for team A and a loss for team B it is one observation with all of the stats from team A and then result is recorded as a win and then a second observation with all of the stats for team B and then the result is recorded as a loss. A tie is treated similarly with all stats for one team recorded and then result as a tie.
#
# These were recorded in an Excel spreadsheet by myself and then saved as a .csv for use with this model. All games from the 2023 season were included, including playoff games. The only exception is one or two games that did not have stats broken down by half, so I could not access the first half statistics. These observations were excluded. I also included "full time goals" incase I decided to use this data in the future to try to use half time stats to predict full time goals. There are some duplicate variables because I ordered the stats in the order they appear on the website, and some things are mentioned in two different categories, so they appear twice.

# %%
df = pd.read_csv('nwsl2023.csv')

# check shape of df
print(df.shape)

# explore observations
print(df.sample(5))

# view breakdown of features
df.info()
# Out:
# (266, 46)
#      ball_possession  total_shots  shots_on_target  big_chances  \
# 34           0.46000           13                5            1
# 260          0.38000            3                2            0
# 210          0.59000            8                2            0
# 193          0.34000            2                0            0
# 150          0.55000            3                0            0
#
#      big_chances_missed  accurate_passes  accurate_passes_percent  \
# 34                    0              163                  0.79000
# 260                   0              115                  0.68000
# 210                   0              195                  0.81000
# 193                   0              101                  0.70000
# 150                   0              157                  0.77000
#
#      fouls_committed  corners  total_shots.1  ...  duels_won  \
# 34                 7        3             13  ...         17
# 260                7        2              3  ...         24
# 210                5        5              8  ...         23
# 193                8        1              2  ...         16
# 150                4        0              3  ...         27
#
#      ground_duels_won  ground_duels_won_percent  aerial_duels_won  \
# 34                 12                   0.44000                 5
# 260                19                   0.51000                 5
# 210                13                   0.38000                10
# 193                10                   0.31000                 6
# 150                21                   0.54000                 6
#
#      aerial_duels_won_percent  successful_dribbles  \
# 34                    0.71000                    6
# 260                   0.83000                    4
# 210                   0.77000                    5
# 193                   0.60000                    2
# 150                   0.60000                    6
#
#      successful_dribbles_percent  result  first_half_goals  full_time_goals
# 34                       0.60000       W                 2                2
# 260                      0.67000       T                 0                0
# 210                      0.56000       W                 0                2
# 193                      0.33000       T                 0                0
# 150                      0.55000       L                 0                0
#
# [5 rows x 46 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ball_possession              266 non-null    float64
#  1   total_shots                  266 non-null    int64
#  2   shots_on_target              266 non-null    int64
#  3   big_chances                  266 non-null    int64
#  4   big_chances_missed           266 non-null    int64
#  5   accurate_passes              266 non-null    int64
#  6   accurate_passes_percent      266 non-null    float64
#  7   fouls_committed              266 non-null    int64
#  8   corners                      266 non-null    int64
#  9   total_shots.1                266 non-null    int64
#  10  shots_off_target             266 non-null    int64
#  11  shots_on_target.1            266 non-null    int64
#  12  blocked_shots                266 non-null    int64
#  13  hit_woodwork                 266 non-null    int64
#  14  shots_inside_box             266 non-null    int64
#  15  shots_outside_box            266 non-null    int64
#  16  passes                       266 non-null    int64
#  17  accurate_passes.1            266 non-null    int64
#  18  accurate_passes_percent.1    266 non-null    float64
#  19  own_half_passes              266 non-null    int64
#  20  opposition_half_passes       266 non-null    float64
#  21  accurate_long_balls          266 non-null    int64
#  22  accurate_long_balls_percent  266 non-null    float64
#  23  accurate_crosses             266 non-null    int64
#  24  accurate_crosses_percent     266 non-null    float64
#  25  throws                       266 non-null    int64
#  26  touches_in_opp_box           12 non-null     float64
#  27  offsides                     266 non-null    int64
#  28  yellow_cards                 266 non-null    int64
#  29  red_cards                    266 non-null    int64
#  30  tackles_won                  266 non-null    int64
#  31  tackles_won_percent          266 non-null    float64
#  32  interceptions                266 non-null    int64
#  33  blocks                       266 non-null    int64
#  34  clearances                   266 non-null    int64
#  35  keeper_saves                 266 non-null    int64
#  36  duels_won                    266 non-null    int64
#  37  ground_duels_won             266 non-null    int64
#  38  ground_duels_won_percent     266 non-null    float64
#  39  aerial_duels_won             266 non-null    int64
#  40  aerial_duels_won_percent     266 non-null    float64
#  41  successful_dribbles          266 non-null    int64
#  42  successful_dribbles_percent  266 non-null    float64
#  43  result                       266 non-null    object
#  44  first_half_goals             266 non-null    int64
#  45  full_time_goals              266 non-null    int64
# dtypes: float64(11), int64(34), object(1)
# memory usage: 95.7+ KB

# %% [markdown]
#  I read in the data and explore it a bit to get a better understanding of it. At this point I notice that there are some duplicate columns denoted by ending in .1 and touches_in_opp_box is mostly null values so I will likely drop those variables. I also have a variable called full time goals. This is a problem because the point of this model is to use data that is available at halftime of a game to predict the outcome, so I will need to drop this as well.

# %%
# Remove columns that end in .1
df = df.loc[:, ~df.columns.str.endswith('.1')]

# Drop specific columns
df = df.drop(['touches_in_opp_box', 'full_time_goals'], axis=1)

# %%
# split the df into features (X) and target (y)
X = df.drop(columns=['result'])
y = df['result']

# scale features to help with model performance later on
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

df_scaled = pd.concat([X_scaled, y], axis=1)

# %% [markdown]
# In this step, I split the dataset into input features (`X`) and the target variable (`y`). The `result` column, which I want to predict, is set as the target, while all other columns are used as features. To improve model performance and ensure no single feature dominates due to its scale, I standardize the features using `StandardScaler`, which transforms the data to have a mean of 0 and a standard deviation of 1. After scaling, I convert the standardized features back into a DataFrame to retain the original column names, making it easier to interpret and use the data in subsequent steps.

# %%
# Compute mutual information scores
mi_scores = mutual_info_classif(X_scaled, y, random_state=0)

# Create a DataFrame to view the results
mi_scores_df = pd.DataFrame({
    'Feature': X.columns,
    'Mutual Information': mi_scores
}).sort_values(by='Mutual Information', ascending=False)

print(mi_scores_df)
# Out:
#                         Feature  Mutual Information
# 1                   total_shots             0.13602
# 38             first_half_goals             0.11524
# 8                       corners             0.09776
# 22                     offsides             0.07132
# 17          accurate_long_balls             0.06899
# 14                       passes             0.06260
# 12             shots_inside_box             0.06074
# 3                   big_chances             0.05662
# 9              shots_off_target             0.05648
# 35     aerial_duels_won_percent             0.05366
# 2               shots_on_target             0.05141
# 37  successful_dribbles_percent             0.04430
# 28                       blocks             0.04093
# 5               accurate_passes             0.03988
# 30                 keeper_saves             0.03802
# 23                 yellow_cards             0.03242
# 26          tackles_won_percent             0.03110
# 0               ball_possession             0.02939
# 32             ground_duels_won             0.02180
# 6       accurate_passes_percent             0.01807
# 13            shots_outside_box             0.01634
# 31                    duels_won             0.01300
# 19             accurate_crosses             0.01081
# 24                    red_cards             0.00583
# 25                  tackles_won             0.00496
# 27                interceptions             0.00094
# 4            big_chances_missed             0.00000
# 36          successful_dribbles             0.00000
# 34             aerial_duels_won             0.00000
# 33     ground_duels_won_percent             0.00000
# 18  accurate_long_balls_percent             0.00000
# 7               fouls_committed             0.00000
# 29                   clearances             0.00000
# 16       opposition_half_passes             0.00000
# 11                 hit_woodwork             0.00000
# 15              own_half_passes             0.00000
# 21                       throws             0.00000
# 20     accurate_crosses_percent             0.00000
# 10                blocked_shots             0.00000

# %% [markdown]
# This analysis uses mutual information (MI) scores to evaluate the relationship between each feature in the dataset and the target variable, `result`. MI measures the dependency between variables, quantifying how much knowing a feature reduces uncertainty about the target. Higher MI scores indicate stronger relationships. The results, sorted in descending order, show that the most informative features include `total_shots` (MI = 0.136), `first_half_goals` (MI = 0.115), and `corners` (MI = 0.098). These features provide the most predictive value for the target. On the other hand, features like `big_chances_missed` and `successful_dribbles` have an MI score of 0.000, suggesting no measurable dependency with the target. This analysis helps identify and prioritize features that are likely to contribute most to model performance.

# %%
# Compute F-statistic and p-values
f_values, p_values = f_classif(X_scaled, y)
pd.set_option('display.float_format', '{:.5f}'.format)

# Create a DataFrame to view the results
anova_df = pd.DataFrame({
    'Feature': X.columns,
    'F-value': f_values,
    'p-value': p_values
}).sort_values(by='F-value', ascending=False)

print(anova_df)
# Out:
#                         Feature  F-value  p-value
# 38             first_half_goals 28.36589  0.00000
# 2               shots_on_target 22.74641  0.00000
# 1                   total_shots 14.02909  0.00000
# 12             shots_inside_box 11.49868  0.00002
# 3                   big_chances  9.73405  0.00008
# 30                 keeper_saves  5.32910  0.00539
# 13            shots_outside_box  5.10794  0.00666
# 9              shots_off_target  4.34675  0.01389
# 31                    duels_won  4.19570  0.01608
# 25                  tackles_won  3.83203  0.02289
# 35     aerial_duels_won_percent  3.08853  0.04723
# 19             accurate_crosses  3.01502  0.05074
# 20     accurate_crosses_percent  2.73592  0.06668
# 10                blocked_shots  2.66634  0.07138
# 28                       blocks  2.55724  0.07944
# 6       accurate_passes_percent  2.52727  0.08182
# 33     ground_duels_won_percent  2.42412  0.09053
# 8                       corners  2.29233  0.10305
# 29                   clearances  2.11051  0.12322
# 7               fouls_committed  1.92740  0.14758
# 36          successful_dribbles  1.74881  0.17600
# 34             aerial_duels_won  1.74847  0.17606
# 4            big_chances_missed  1.58367  0.20717
# 26          tackles_won_percent  1.57220  0.20953
# 11                 hit_woodwork  1.51176  0.22243
# 23                 yellow_cards  1.40028  0.24836
# 27                interceptions  1.30614  0.27261
# 22                     offsides  1.16704  0.31289
# 32             ground_duels_won  1.11246  0.33029
# 24                    red_cards  1.01397  0.36419
# 17          accurate_long_balls  0.82552  0.43914
# 37  successful_dribbles_percent  0.81559  0.44349
# 18  accurate_long_balls_percent  0.79389  0.45317
# 15              own_half_passes  0.77525  0.46164
# 5               accurate_passes  0.68391  0.50553
# 16       opposition_half_passes  0.35478  0.70166
# 14                       passes  0.25184  0.77756
# 21                       throws  0.18095  0.83458
# 0               ball_possession  0.01737  0.98278

# %% [markdown]
# In this step, the F-statistic and p-values are computed to evaluate the relationship between each feature and the target variable, `result`. The F-statistic measures how well each feature explains the variance in the target variable, while the p-value assesses the statistical significance of that relationship. A lower p-value (typically less than 0.05) suggests that the feature is statistically significant, meaning it has a meaningful impact on the target variable. For this analysis, we will follow the rule of considering only features with a p-value less than 0.05.
#
# Features with low p-values, such as `first_half_goals` (F = 28.36589, p = 0.00000), `shots_on_target` (F = 22.74641, p = 0.00000), and `total_shots` (F = 14.02909, p = 0.00000), are deemed statistically significant and will be prioritized for model inclusion. Other features like `keeper_saves` (F = 5.32910, p = 0.00539) and `shots_outside_box` (F = 5.10794, p = 0.00666) also have low p-values and contribute meaningfully to the model. On the other hand, features like `ball_possession` (F = 0.01737, p = 0.98278) and `throws` (F = 0.18095, p = 0.83458) have very high p-values, indicating that they do not significantly affect the target variable and will likely be excluded from further analysis.

# %%
# Train a Random Forest model
rf = RandomForestClassifier(random_state=0)
rf.fit(X_scaled, y)

# Get feature importances
feature_importances = rf.feature_importances_

# Create a DataFrame to view the results
rf_importances_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

print(rf_importances_df)
# Out:
#                         Feature  Importance
# 1                   total_shots     0.04630
# 38             first_half_goals     0.04529
# 31                    duels_won     0.04022
# 37  successful_dribbles_percent     0.03563
# 5               accurate_passes     0.03535
# 15              own_half_passes     0.03514
# 35     aerial_duels_won_percent     0.03493
# 20     accurate_crosses_percent     0.03471
# 2               shots_on_target     0.03390
# 33     ground_duels_won_percent     0.03375
# 12             shots_inside_box     0.03101
# 36          successful_dribbles     0.03100
# 29                   clearances     0.03044
# 17          accurate_long_balls     0.03014
# 6       accurate_passes_percent     0.02943
# 16       opposition_half_passes     0.02831
# 0               ball_possession     0.02776
# 27                interceptions     0.02726
# 14                       passes     0.02719
# 18  accurate_long_balls_percent     0.02632
# 7               fouls_committed     0.02607
# 26          tackles_won_percent     0.02582
# 21                       throws     0.02556
# 25                  tackles_won     0.02509
# 8                       corners     0.02454
# 32             ground_duels_won     0.02307
# 9              shots_off_target     0.02191
# 34             aerial_duels_won     0.02173
# 28                       blocks     0.02113
# 13            shots_outside_box     0.01975
# 30                 keeper_saves     0.01957
# 10                blocked_shots     0.01927
# 19             accurate_crosses     0.01773
# 22                     offsides     0.01408
# 3                   big_chances     0.01079
# 23                 yellow_cards     0.00700
# 4            big_chances_missed     0.00622
# 11                 hit_woodwork     0.00526
# 24                    red_cards     0.00134

# %% [markdown]
# In this part, we train a Random Forest classifier model using the features and target variable, and extract the feature importances. A Random Forest is an ensemble of decision trees, where each tree is built using random subsets of both data and features. This randomness helps prevent overfitting, leading to better generalization. After training the model, the `feature_importances_` attribute provides the importance score for each feature, indicating how influential each one is in the model's predictions.
#
# For example, `total_shots` (0.046296) is the most important feature, followed closely by `first_half_goals` (0.045292). These features have the highest contributions to the Random Forest's decision-making process. Other features like `duels_won` (0.040219) and `successful_dribbles_percent` (0.035631) also play significant roles, but with slightly lower importance scores. Features with lower importance, such as `red_cards` (0.001335) and `hit_woodwork` (0.005260), contribute less to the model's ability to predict outcomes. By understanding the feature importances, we can identify the most influential factors driving the model's predictions and gain insights into what the model considers most relevant.

# %% [markdown]
# Across all three analyses—Mutual Information, ANOVA, and Random Forest feature importance—full-time goals consistently emerged as the most influential feature, highlighting its strong predictive value. Shot-related metrics such as total shots, shots on target, and shots inside the box also ranked highly across methods, confirming their importance in modeling outcomes. Mutual Information and ANOVA provided statistical significance insights, while Random Forest emphasized feature contributions through nonlinear interactions, bringing additional perspective. Features like accurate passes percent and keeper saves showed moderate importance, whereas metrics like hit woodwork and red cards consistently had negligible influence, suggesting they could be excluded in future models. Together, these results offer a robust view of which features are most relevant for predictive modeling in this dataset.

# %%
# Filter features where p-value < 0.05 (ANOVA test)
anova_selected_df = anova_df[anova_df['p-value'] < 0.05]

# Assuming X_scaled is your scaled feature matrix and y is your target
X_selected = X_scaled[anova_selected_df['Feature']]  # Select only the features that passed the p-value condition

# Calculate Mutual Information scores for selected features
mi_selector = SelectKBest(score_func=mutual_info_classif, k='all')
mi_selector.fit(X_selected, y)
mi_scores = mi_selector.scores_

# Calculate Random Forest feature importances
rf = RandomForestClassifier(random_state=0)
rf.fit(X_selected, y)
rf_importances = rf.feature_importances_

# Create a new DataFrame to combine everything
final_df_10f = pd.DataFrame({
    'Feature': anova_selected_df['Feature'],
    'F-value': anova_selected_df['F-value'],
    'p-value': anova_selected_df['p-value'],
    'MI_Score': mi_scores,
    'RF_Importance': rf_importances
})

# Show the resulting DataFrame
print(final_df_10f)
# Out:
#                      Feature  F-value  p-value  MI_Score  RF_Importance
# 38          first_half_goals 28.36589  0.00000   0.12240        0.07485
# 2            shots_on_target 22.74641  0.00000   0.09223        0.09226
# 1                total_shots 14.02909  0.00000   0.13587        0.11227
# 12          shots_inside_box 11.49868  0.00002   0.01059        0.08848
# 3                big_chances  9.73405  0.00008   0.03900        0.04700
# 30              keeper_saves  5.32910  0.00539   0.00000        0.07995
# 13         shots_outside_box  5.10794  0.00666   0.00000        0.05911
# 9           shots_off_target  4.34675  0.01389   0.03344        0.07637
# 31                 duels_won  4.19570  0.01608   0.00000        0.12476
# 25               tackles_won  3.83203  0.02289   0.03791        0.10367
# 35  aerial_duels_won_percent  3.08853  0.04723   0.05879        0.14128

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize each metric
scaler = MinMaxScaler()

# Normalize F-value (larger is better)
final_df_10f['F-value_norm'] = scaler.fit_transform(final_df_10f[['F-value']])

# Normalize MI Score (larger is better)
final_df_10f['MI_Score_norm'] = scaler.fit_transform(final_df_10f[['MI_Score']])

# Normalize RF Importance (larger is better)
final_df_10f['RF_Importance_norm'] = scaler.fit_transform(final_df_10f[['RF_Importance']])

# Normalize p-value (smaller is better, so invert it)
final_df_10f['p-value_inv'] = 1 - scaler.fit_transform(final_df_10f[['p-value']])

# Combine the normalized scores into a composite score (you can adjust the weights)
final_df_10f['Composite_Score'] = (
    0.4 * final_df_10f['F-value_norm'] +    # Give more weight to F-value
    0.3 * final_df_10f['MI_Score_norm'] +  # Moderate weight to MI score
    0.2 * final_df_10f['RF_Importance_norm'] +  # Less weight to RF importance
    0.1 * final_df_10f['p-value_inv']      # Less weight to p-value (inverted)
)

# Sort features by composite score in descending order
final_df_10f_sorted = final_df_10f.sort_values(by='Composite_Score', ascending=False)

# Show the top features based on the composite score
top_5_features = final_df_10f_sorted.head(5)
print(top_5_features[['Feature', 'F-value', 'p-value', 'MI_Score', 'RF_Importance', 'Composite_Score']])
# Out:
#                      Feature  F-value  p-value  MI_Score  RF_Importance  \
# 38          first_half_goals 28.36589  0.00000   0.12240        0.07485
# 1                total_shots 14.02909  0.00000   0.13587        0.11227
# 2            shots_on_target 22.74641  0.00000   0.09223        0.09226
# 12          shots_inside_box 11.49868  0.00002   0.01059        0.08848
# 35  aerial_duels_won_percent  3.08853  0.04723   0.05879        0.14128
#
#     Composite_Score
# 38          0.82934
# 1           0.71158
# 2           0.71072
# 12          0.34442
# 35          0.32981

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize each metric
scaler = MinMaxScaler()

# Normalize F-value (larger is better)
final_df_10f['F-value_norm'] = scaler.fit_transform(final_df_10f[['F-value']])

# Normalize MI Score (larger is better)
final_df_10f['MI_Score_norm'] = scaler.fit_transform(final_df_10f[['MI_Score']])

# Normalize RF Importance (larger is better)
final_df_10f['RF_Importance_norm'] = scaler.fit_transform(final_df_10f[['RF_Importance']])

# Normalize p-value (smaller is better, so we invert it)
final_df_10f['p-value_inv'] = 1 - scaler.fit_transform(final_df_10f[['p-value']])

# Combine the normalized scores into a composite score
final_df_10f['Composite_Score'] = (
    0.4 * final_df_10f['F-value_norm'] +    # Give more weight to F-value
    0.3 * final_df_10f['MI_Score_norm'] +  # Moderate weight to MI score
    0.2 * final_df_10f['RF_Importance_norm'] +  # Less weight to RF importance
    0.1 * final_df_10f['p-value_inv']      # Less weight to p-value (inverted)
)

# Sort features by composite score in descending order
final_df_sorted = final_df_10f.sort_values(by='Composite_Score', ascending=False)

# Show the top 5 features based on the composite score
top_5_features = final_df_sorted.head(5)
print(top_5_features[['Feature', 'F-value', 'p-value', 'MI_Score', 'RF_Importance', 'Composite_Score']])
# Out:
#                      Feature  F-value  p-value  MI_Score  RF_Importance  \
# 38          first_half_goals 28.36589  0.00000   0.12240        0.07485
# 1                total_shots 14.02909  0.00000   0.13587        0.11227
# 2            shots_on_target 22.74641  0.00000   0.09223        0.09226
# 12          shots_inside_box 11.49868  0.00002   0.01059        0.08848
# 35  aerial_duels_won_percent  3.08853  0.04723   0.05879        0.14128
#
#     Composite_Score
# 38          0.82934
# 1           0.71158
# 2           0.71072
# 12          0.34442
# 35          0.32981

# %% [markdown]
# In this analysis, I selected a subset of features for modeling based on their statistical significance and predictive power. First, I applied an ANOVA test to assess the relationship between each feature and the target variable, retaining only the features with a p-value < 0.05, indicating a significant association with the target. This step helped filter out features that are less likely to contribute meaningfully to the model.
#
# Next, I evaluated the Mutual Information (MI) and Random Forest (RF) importance scores for the selected features. MI measures the amount of information shared between each feature and the target, while RF importance ranks features based on their ability to improve predictive accuracy in a random forest model. Both metrics provide additional insight into the strength of each feature's relationship with the target variable, further guiding feature selection.
#
# To further refine the selection, I normalized the F-value, MI score, RF importance, and p-value (inverted) for each feature and combined them into a composite score. This composite score allowed me to rank the features based on a combination of their statistical significance and predictive power. The features with the highest composite scores are expected to contribute the most to the model's predictive performance.
#
# The resulting top 5 features, based on their composite score, are:
#
# - **Total Shots**
# - **Shots on Target**
# - **First Half Goals**
# - **Shots Inside Box**
# - **Keeper Saves**
#
# These features not only passed the ANOVA test but also scored highly in terms of their mutual information and random forest importance. By focusing on statistically significant features with high predictive power, this process ensures that the selected features are both relevant and valuable, thereby improving the efficiency and accuracy of the model.
#
# Using these top 5 features in the model will allow us to capture the most important patterns in the data while minimizing noise from less informative features. This should enhance model interpretability and performance when predicting the target variable.

# %%
# Extract the top 5 feature names
top_5_feature_names = top_5_features['Feature'].tolist()

# Filter X_scaled to include only the columns that correspond to the top 5 features
X_selected = X_scaled[top_5_feature_names]

# Combine X_selected with y into df_selected
df_selected = pd.concat([X_selected, y], axis=1)

# Show the resulting DataFrame
print(df_selected)
# Out:
#      first_half_goals  shots_on_target  total_shots  shots_inside_box  \
# 0             1.77902          0.52431     -0.58568          -1.26177
# 1             1.77902         -0.11839      0.67578           1.29704
# 2             1.77902          3.09510      2.88334           3.42938
# 3            -0.75156         -1.40379     -0.90104          -0.40883
# 4            -0.75156         -1.40379     -1.53177          -1.26177
# ..                ...              ...          ...               ...
# 261          -0.75156         -0.76109      0.04505          -0.40883
# 262          -0.75156         -1.40379     -1.21641          -0.83530
# 263          -0.75156          0.52431     -0.58568          -0.83530
# 264           0.51373         -0.76109     -1.21641          -1.26177
# 265           1.77902         -0.11839      0.04505           0.44410
#
#      big_chances result
# 0        0.22352      W
# 1        1.30452      L
# 2        3.46653      W
# 3       -0.85749      L
# 4       -0.85749      L
# ..           ...    ...
# 261     -0.85749      T
# 262     -0.85749      L
# 263     -0.85749      W
# 264      0.22352      L
# 265      0.22352      W
#
# [266 rows x 6 columns]

# %% [markdown]
# # Model

# %%
# Split the data with stratification based on the 'result' column using top features
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, stratify=df_selected['result'], test_size=0.25, random_state=101)

# Split the data with stratification based on the 'result' column using all features
X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(X_scaled, y, stratify=df_scaled['result'], test_size=0.25, random_state=101)

# %% [markdown]
# First I have to split the model into test and train sets. We use stratification because with this classification model we have unbalanced classes, so we want to be sure that we are splitting our testing and training sets evenly with respect to the class. I made a training set and testing set with all the features and with the top 5 and we try the logistic regression classification model first.

# %%
# Trying Logistic Regression Model with all features

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Initialize the Logistic Regression model
model_all = LogisticRegression(max_iter=200, class_weight='balanced')

# Train the model
model_all.fit(X_train_all, y_train_all)

# Evaluate the model on the test set
y_pred_all = model_all.predict(X_test_all)

# Check performance
accuracy_all_train = model_all.score(X_train_all, y_train_all)
print(f'Train Set Accuracy: {accuracy_all_train}')
accuracy_all = model_all.score(X_test_all, y_test_all)
print(f'Test Set Accuracy: {accuracy_all}')
print(classification_report(y_test_all, y_pred_all))

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test_all, y_pred_all, labels=model_all.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_all.classes_)
disp.plot(cmap='Blues')
# Out:
# Train Set Accuracy: 0.6582914572864321
# Test Set Accuracy: 0.44776119402985076
#               precision    recall  f1-score   support
#
#            L       0.46      0.52      0.49        25
#            T       0.33      0.24      0.28        17
#            W       0.48      0.52      0.50        25
#
#     accuracy                           0.45        67
#    macro avg       0.43      0.43      0.42        67
# weighted avg       0.44      0.45      0.44        67

# %%
# Trying Logistic Regression Model with top 5 features

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Initialize the Logistic Regression model
model = LogisticRegression(max_iter=200, class_weight='balanced')

# Train the model
model.fit(X_train, y_train)

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Check accuracy
accuracy_train = model.score(X_train, y_train)
print(f'Train Set Accuracy: {accuracy_train}')
accuracy = model.score(X_test, y_test)
print(f'Test Set Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues')
# Out:
# Train Set Accuracy: 0.5477386934673367
# Test Set Accuracy: 0.4626865671641791
#               precision    recall  f1-score   support
#
#            L       0.48      0.44      0.46        25
#            T       0.25      0.24      0.24        17
#            W       0.57      0.64      0.60        25
#
#     accuracy                           0.46        67
#    macro avg       0.43      0.44      0.43        67
# weighted avg       0.46      0.46      0.46        67

# %% [markdown]
# Here we can see that the model is more accurate with the top 5 variables, so we will limit our usage to the top 5 performing variables instead of all of them to help cut down on noise and create a simpler, easier to understand, and more accurate model. We have about 45% overall accuracy with our model with all variables, and about 55% with our model with the top 5 variables, but we will look at our accuracy predictions closer after we have tried a few different models. We can also see that our test set is performing slightly better but similar to our train set, so we are likely not suffering from overfitting.

# %%
# Map the result values to points bc we need numerical outputs for neural networks
num_map = {'W': 2, 'T': 1, 'L': 0}
df_selected['num'] = df_selected['result'].map(num_map)

# Create df_num with only the numerical column instead of result
df_num = df_selected.drop(columns=['result'])

y_num = df_num['num']

# Split the data with stratification based on the 'result' column
X_train_num, X_test_num, y_train_num, y_test_num = train_test_split(X_selected, y_num, stratify=df_num['num'], test_size=0.25, random_state=101)

# %% [markdown]
# Now we want to use a nueral network for prediction, which requires numerical outputs. To use this, we encode a Loss as 0, a Tie as 1, and a Win as 2.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# Number of classes
num_classes = 3  # W, L, T

# Initialize the model
model = Sequential()

# Define the input shape using the Input layer as the first layer
model.add(Input(shape=(X_train_num.shape[1],)))

# Add a Dense layer with 64 neurons and ReLU activation ]
model.add(Dense(64, activation='relu'))

# Output layer with 3 neurons and softmax activation for classification
model.add(Dense(3, activation='softmax'))  # 3 classes, softmax is appropriate for multi-class classification

# Compile the model with Adam optimizer and sparse categorical crossentropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_num, y_train_num, epochs=100, batch_size=32, validation_split=0.2)


print('\n\n\n')
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_num, y_test_num)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Predictions (optional)
predictions = model.predict(X_test_num)
predicted_classes = tf.argmax(predictions, axis=1)  # Convert probabilities to class indices

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_num, y_test_num)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Evaluate the model on the train set
train_loss, train_accuracy = model.evaluate(X_train_num, y_train_num)
print(f"Train Accuracy: {train_accuracy}")

# For confusion matrix and plotting
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Correct class labels
class_labels = [0, 1, 2]

# Create the confusion matrix
cm = confusion_matrix(y_test_num, predicted_classes, labels=class_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_labels,
    yticklabels=class_labels
)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

print('\n\n\n')
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_num, y_test_num)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Evaluate the model on the train set
train_loss, train_accuracy = model.evaluate(X_train_num, y_train_num)
print(f"Train Accuracy: {train_accuracy}")
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2996 - loss: 1.3036 - val_accuracy: 0.4250 - val_loss: 1.0684
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3062 - loss: 1.2565 - val_accuracy: 0.5000 - val_loss: 1.0357
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3143 - loss: 1.1868 - val_accuracy: 0.5750 - val_loss: 1.0121
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3850 - loss: 1.1215 - val_accuracy: 0.5250 - val_loss: 0.9956
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4177 - loss: 1.0786 - val_accuracy: 0.5500 - val_loss: 0.9831
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4698 - loss: 1.0374 - val_accuracy: 0.5250 - val_loss: 0.9750
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4510 - loss: 1.0558 - val_accuracy: 0.5750 - val_loss: 0.9710
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4585 - loss: 1.0109 - val_accuracy: 0.6000 - val_loss: 0.9692
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5238 - loss: 0.9478 - val_accuracy: 0.6000 - val_loss: 0.9687
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4704 - loss: 0.9793 - val_accuracy: 0.6500 - val_loss: 0.9686
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5480 - loss: 0.9667 - val_accuracy: 0.6250 - val_loss: 0.9702
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5044 - loss: 0.9802 - val_accuracy: 0.6250 - val_loss: 0.9728
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5612 - loss: 0.9349 - val_accuracy: 0.6000 - val_loss: 0.9732
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5993 - loss: 0.8966 - val_accuracy: 0.6000 - val_loss: 0.9755
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5893 - loss: 0.8860 - val_accuracy: 0.6000 - val_loss: 0.9759
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5558 - loss: 0.9394 - val_accuracy: 0.6000 - val_loss: 0.9770
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5562 - loss: 0.9327 - val_accuracy: 0.6000 - val_loss: 0.9768
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5925 - loss: 0.9095 - val_accuracy: 0.6000 - val_loss: 0.9777
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5643 - loss: 0.8957 - val_accuracy: 0.6000 - val_loss: 0.9776
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5842 - loss: 0.8749 - val_accuracy: 0.5750 - val_loss: 0.9785
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5679 - loss: 0.8891 - val_accuracy: 0.5750 - val_loss: 0.9788
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5724 - loss: 0.8951 - val_accuracy: 0.5750 - val_loss: 0.9780
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5698 - loss: 0.9054 - val_accuracy: 0.5750 - val_loss: 0.9787
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5637 - loss: 0.9100 - val_accuracy: 0.5750 - val_loss: 0.9791
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5277 - loss: 0.9147 - val_accuracy: 0.5750 - val_loss: 0.9789
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5980 - loss: 0.8734 - val_accuracy: 0.5750 - val_loss: 0.9792
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5916 - loss: 0.8598 - val_accuracy: 0.5750 - val_loss: 0.9799
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5785 - loss: 0.8554 - val_accuracy: 0.6000 - val_loss: 0.9797
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6245 - loss: 0.8375 - val_accuracy: 0.5750 - val_loss: 0.9807
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6132 - loss: 0.8515 - val_accuracy: 0.5750 - val_loss: 0.9804
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5658 - loss: 0.8677 - val_accuracy: 0.6000 - val_loss: 0.9803
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5967 - loss: 0.8482 - val_accuracy: 0.6000 - val_loss: 0.9824
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6261 - loss: 0.8086 - val_accuracy: 0.5750 - val_loss: 0.9842
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6283 - loss: 0.7986 - val_accuracy: 0.5750 - val_loss: 0.9854
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6052 - loss: 0.8377 - val_accuracy: 0.5750 - val_loss: 0.9875
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5995 - loss: 0.8516 - val_accuracy: 0.5750 - val_loss: 0.9876
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6139 - loss: 0.8096 - val_accuracy: 0.5500 - val_loss: 0.9889
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6230 - loss: 0.8314 - val_accuracy: 0.5500 - val_loss: 0.9892
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6398 - loss: 0.7888 - val_accuracy: 0.5250 - val_loss: 0.9910
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6624 - loss: 0.7605 - val_accuracy: 0.5250 - val_loss: 0.9922
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5986 - loss: 0.8104 - val_accuracy: 0.5250 - val_loss: 0.9933
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5786 - loss: 0.8574 - val_accuracy: 0.5250 - val_loss: 0.9944
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6233 - loss: 0.7942 - val_accuracy: 0.5250 - val_loss: 0.9971
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6513 - loss: 0.7830 - val_accuracy: 0.5500 - val_loss: 0.9990
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6076 - loss: 0.8125 - val_accuracy: 0.5500 - val_loss: 1.0004
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6075 - loss: 0.8235 - val_accuracy: 0.5500 - val_loss: 1.0016
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6353 - loss: 0.7799 - val_accuracy: 0.5500 - val_loss: 1.0021
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6427 - loss: 0.7969 - val_accuracy: 0.5500 - val_loss: 1.0042
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6655 - loss: 0.7676 - val_accuracy: 0.5500 - val_loss: 1.0055
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6651 - loss: 0.7705 - val_accuracy: 0.5500 - val_loss: 1.0077
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6719 - loss: 0.7893 - val_accuracy: 0.5500 - val_loss: 1.0072
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6267 - loss: 0.8073 - val_accuracy: 0.5500 - val_loss: 1.0088
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6827 - loss: 0.7417 - val_accuracy: 0.5500 - val_loss: 1.0105
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6844 - loss: 0.7614 - val_accuracy: 0.5500 - val_loss: 1.0121
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6237 - loss: 0.8026 - val_accuracy: 0.5500 - val_loss: 1.0155
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6827 - loss: 0.7635 - val_accuracy: 0.5500 - val_loss: 1.0153
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6787 - loss: 0.7650 - val_accuracy: 0.5500 - val_loss: 1.0191
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7343 - loss: 0.7215 - val_accuracy: 0.5250 - val_loss: 1.0207
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6531 - loss: 0.7647 - val_accuracy: 0.5250 - val_loss: 1.0226
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6695 - loss: 0.7832 - val_accuracy: 0.5500 - val_loss: 1.0239
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6846 - loss: 0.7475 - val_accuracy: 0.5500 - val_loss: 1.0254
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6695 - loss: 0.7552 - val_accuracy: 0.5500 - val_loss: 1.0272
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7180 - loss: 0.7104 - val_accuracy: 0.5500 - val_loss: 1.0289
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7132 - loss: 0.6912 - val_accuracy: 0.5500 - val_loss: 1.0315
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6923 - loss: 0.7468 - val_accuracy: 0.5500 - val_loss: 1.0361
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7153 - loss: 0.7089 - val_accuracy: 0.5250 - val_loss: 1.0393
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6948 - loss: 0.7391 - val_accuracy: 0.5250 - val_loss: 1.0412
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7135 - loss: 0.7323 - val_accuracy: 0.5250 - val_loss: 1.0427
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7253 - loss: 0.7195 - val_accuracy: 0.5250 - val_loss: 1.0453
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6810 - loss: 0.7427 - val_accuracy: 0.5500 - val_loss: 1.0465
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7343 - loss: 0.7013 - val_accuracy: 0.5500 - val_loss: 1.0472
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6852 - loss: 0.7621 - val_accuracy: 0.5250 - val_loss: 1.0501
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7352 - loss: 0.7105 - val_accuracy: 0.5500 - val_loss: 1.0525
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7195 - loss: 0.7033 - val_accuracy: 0.5250 - val_loss: 1.0554
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7307 - loss: 0.6890 - val_accuracy: 0.5500 - val_loss: 1.0574
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6978 - loss: 0.7270 - val_accuracy: 0.5500 - val_loss: 1.0593
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7177 - loss: 0.6956 - val_accuracy: 0.5500 - val_loss: 1.0634
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7325 - loss: 0.6958 - val_accuracy: 0.5500 - val_loss: 1.0647
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7186 - loss: 0.6777 - val_accuracy: 0.5250 - val_loss: 1.0685
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7425 - loss: 0.6763 - val_accuracy: 0.5250 - val_loss: 1.0698
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6852 - loss: 0.7093 - val_accuracy: 0.5250 - val_loss: 1.0733
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6994 - loss: 0.6853 - val_accuracy: 0.5250 - val_loss: 1.0733
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7255 - loss: 0.6816 - val_accuracy: 0.5500 - val_loss: 1.0744
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7381 - loss: 0.6694 - val_accuracy: 0.5500 - val_loss: 1.0772
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6876 - loss: 0.6993 - val_accuracy: 0.5500 - val_loss: 1.0784
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7007 - loss: 0.6748 - val_accuracy: 0.5500 - val_loss: 1.0812
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7553 - loss: 0.6602 - val_accuracy: 0.5500 - val_loss: 1.0816
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7210 - loss: 0.6604 - val_accuracy: 0.5500 - val_loss: 1.0845
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7128 - loss: 0.6790 - val_accuracy: 0.5500 - val_loss: 1.0869
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7467 - loss: 0.6391 - val_accuracy: 0.5500 - val_loss: 1.0905
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7454 - loss: 0.6504 - val_accuracy: 0.5250 - val_loss: 1.0903
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7770 - loss: 0.6077 - val_accuracy: 0.5500 - val_loss: 1.0956
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7171 - loss: 0.6686 - val_accuracy: 0.5500 - val_loss: 1.0978
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7349 - loss: 0.6554 - val_accuracy: 0.5500 - val_loss: 1.1003
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7692 - loss: 0.6439 - val_accuracy: 0.5500 - val_loss: 1.1010
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7527 - loss: 0.6335 - val_accuracy: 0.5500 - val_loss: 1.1016
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7396 - loss: 0.6201 - val_accuracy: 0.5500 - val_loss: 1.1046
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7548 - loss: 0.6339 - val_accuracy: 0.5500 - val_loss: 1.1060
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7040 - loss: 0.6843 - val_accuracy: 0.5250 - val_loss: 1.1055
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7573 - loss: 0.6343 - val_accuracy: 0.5000 - val_loss: 1.1100
#
#
#
#
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5733 - loss: 0.9283
# Test Loss: 0.9808450937271118, Test Accuracy: 0.5373134613037109
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5733 - loss: 0.9283
# Test Loss: 0.9808450937271118, Test Accuracy: 0.5373134613037109
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7315 - loss: 0.6702
# Train Accuracy: 0.6984924674034119
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5733 - loss: 0.9283
# Test Loss: 0.9808450937271118, Test Accuracy: 0.5373134613037109
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7315 - loss: 0.6702
# Train Accuracy: 0.6984924674034119

# %% [markdown]
# The model's accuracy is approximately 53.7%, with relatively few ties predicted. This outcome makes sense because, as we've discussed, neural networks can sometimes take shortcuts during training. The training accuracy is about 57%, which is fairly close to the test accuracy, suggesting that overfitting is unlikely. Overfitting typically happens when a model performs well on the training data but poorly on new, unseen data, but in this case, the model appears to generalize well.
#
# In terms of loss, the test loss is 0.97, and the training loss is 0.89. Loss represents how well the model's predictions match the actual outcomes. A lower loss value indicates that the model's predictions are closer to the true labels. The relatively close values for training and test loss further support the idea that the model is not overfitting and is performing consistently on both datasets.

# %%
# Count occurrences of each class
class_counts = y_num.value_counts()

# Calculate normalized class weights (optional, based on class distribution)
total_samples = len(y_num)
class_weight = {0: total_samples / class_counts[0],
                1: total_samples / class_counts[1],
                2: total_samples / class_counts[2]}
print(f"Class weights: {class_weight}")

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from tensorflow.keras.optimizers import Adam

# Number of classes
num_classes = 3  # W, L, T

# Initialize the model
model = Sequential()

# Define the input shape using the Input layer as the first layer
model.add(Input(shape=(X_train_num.shape[1],)))

# Add more Dense layers with more neurons and ReLU activation
model.add(Dense(128, activation='relu'))  # Added more neurons
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Additional hidden layer with 64 neurons
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Add a third hidden layer with 32 neurons
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Output layer with 3 neurons and softmax activation for classification
model.add(Dense(3, activation='softmax'))  # 3 classes, softmax is appropriate for multi-class classification

# Compile the model with Adam optimizer and sparse categorical crossentropy loss
optimizer = Adam(learning_rate=0.001)  # Optionally, adjust the learning rate
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model with increased epochs (e.g., 200 epochs) and batch size of 64
model.fit(X_train_num, y_train_num, epochs=200, batch_size=64, validation_split=0.2, class_weight=class_weight)

print('\n\n\n')
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_num, y_test_num)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Predictions (optional)
predictions = model.predict(X_test_num)
predicted_classes = tf.argmax(predictions, axis=1)  # Convert probabilities to class indices

# For confusion matrix and plotting
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Correct class labels
class_labels = [0, 1, 2]

# Create the confusion matrix
cm = confusion_matrix(y_test_num, predicted_classes, labels=class_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_labels,
    yticklabels=class_labels
)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()


print('\n\n\n')
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_num, y_test_num)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Evaluate the model on the train set
train_loss, train_accuracy = model.evaluate(X_train_num, y_train_num)
print(f"Train Accuracy: {train_accuracy}")
# Out:
# Class weights: {0: 2.66, 1: 4.03030303030303, 2: 2.66}
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.3511 - loss: 3.3322 - val_accuracy: 0.4000 - val_loss: 1.1019
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3507 - loss: 3.3445 - val_accuracy: 0.3500 - val_loss: 1.0934
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3849 - loss: 3.2549 - val_accuracy: 0.3500 - val_loss: 1.0812
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3747 - loss: 3.3711 - val_accuracy: 0.3750 - val_loss: 1.0691
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4177 - loss: 3.2569 - val_accuracy: 0.4000 - val_loss: 1.0599
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5187 - loss: 3.0415 - val_accuracy: 0.4000 - val_loss: 1.0551
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4081 - loss: 3.2028 - val_accuracy: 0.4000 - val_loss: 1.0483
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4349 - loss: 3.1373 - val_accuracy: 0.4500 - val_loss: 1.0418
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4623 - loss: 3.1168 - val_accuracy: 0.4500 - val_loss: 1.0356
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4812 - loss: 3.0022 - val_accuracy: 0.4500 - val_loss: 1.0311
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5152 - loss: 2.9545 - val_accuracy: 0.4500 - val_loss: 1.0290
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5259 - loss: 2.9211 - val_accuracy: 0.4500 - val_loss: 1.0279
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4910 - loss: 3.0523 - val_accuracy: 0.4500 - val_loss: 1.0279
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4995 - loss: 3.0924 - val_accuracy: 0.4500 - val_loss: 1.0274
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5032 - loss: 2.9878 - val_accuracy: 0.4500 - val_loss: 1.0245
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5157 - loss: 3.0872 - val_accuracy: 0.4500 - val_loss: 1.0188
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5380 - loss: 2.9325 - val_accuracy: 0.4500 - val_loss: 1.0139
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5545 - loss: 2.8836 - val_accuracy: 0.5000 - val_loss: 1.0083
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5826 - loss: 2.8695 - val_accuracy: 0.5000 - val_loss: 1.0035
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5517 - loss: 2.8620 - val_accuracy: 0.4750 - val_loss: 0.9989
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5752 - loss: 2.8296 - val_accuracy: 0.5000 - val_loss: 0.9948
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5509 - loss: 2.7457 - val_accuracy: 0.5000 - val_loss: 0.9925
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5560 - loss: 2.8705 - val_accuracy: 0.5000 - val_loss: 0.9912
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5536 - loss: 2.8169 - val_accuracy: 0.5000 - val_loss: 0.9911
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5494 - loss: 2.8260 - val_accuracy: 0.5000 - val_loss: 0.9908
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5622 - loss: 2.6997 - val_accuracy: 0.5000 - val_loss: 0.9901
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5290 - loss: 2.9256 - val_accuracy: 0.5000 - val_loss: 0.9888
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5764 - loss: 2.8739 - val_accuracy: 0.5000 - val_loss: 0.9886
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5208 - loss: 2.7802 - val_accuracy: 0.5000 - val_loss: 0.9878
# Epoch 30/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5725 - loss: 2.7422 - val_accuracy: 0.5000 - val_loss: 0.9885
# Epoch 31/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5557 - loss: 2.6984 - val_accuracy: 0.5000 - val_loss: 0.9857
# Epoch 32/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5800 - loss: 2.7579 - val_accuracy: 0.5000 - val_loss: 0.9826
# Epoch 33/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5334 - loss: 2.6867 - val_accuracy: 0.5000 - val_loss: 0.9806
# Epoch 34/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5877 - loss: 2.7004 - val_accuracy: 0.5000 - val_loss: 0.9782
# Epoch 35/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5435 - loss: 2.7118 - val_accuracy: 0.5000 - val_loss: 0.9737
# Epoch 36/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6384 - loss: 2.5760 - val_accuracy: 0.5000 - val_loss: 0.9709
# Epoch 37/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5532 - loss: 2.7418 - val_accuracy: 0.5000 - val_loss: 0.9706
# Epoch 38/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5643 - loss: 2.7282 - val_accuracy: 0.5000 - val_loss: 0.9705
# Epoch 39/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6226 - loss: 2.5658 - val_accuracy: 0.5000 - val_loss: 0.9732
# Epoch 40/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6093 - loss: 2.5490 - val_accuracy: 0.5000 - val_loss: 0.9782
# Epoch 41/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5667 - loss: 2.6494 - val_accuracy: 0.5000 - val_loss: 0.9824
# Epoch 42/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5717 - loss: 2.6137 - val_accuracy: 0.5000 - val_loss: 0.9868
# Epoch 43/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6069 - loss: 2.6444 - val_accuracy: 0.5000 - val_loss: 0.9892
# Epoch 44/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6175 - loss: 2.5029 - val_accuracy: 0.5250 - val_loss: 0.9904
# Epoch 45/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6343 - loss: 2.6118 - val_accuracy: 0.5250 - val_loss: 0.9904
# Epoch 46/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5964 - loss: 2.6461 - val_accuracy: 0.5250 - val_loss: 0.9918
# Epoch 47/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6399 - loss: 2.4826 - val_accuracy: 0.5250 - val_loss: 0.9922
# Epoch 48/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5784 - loss: 2.6583 - val_accuracy: 0.5250 - val_loss: 0.9946
# Epoch 49/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5784 - loss: 2.6276 - val_accuracy: 0.5250 - val_loss: 0.9995
# Epoch 50/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6160 - loss: 2.4525 - val_accuracy: 0.5250 - val_loss: 1.0038
# Epoch 51/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5631 - loss: 2.5381 - val_accuracy: 0.5250 - val_loss: 1.0060
# Epoch 52/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6343 - loss: 2.4397 - val_accuracy: 0.5250 - val_loss: 1.0045
# Epoch 53/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6987 - loss: 2.4295 - val_accuracy: 0.5000 - val_loss: 1.0026
# Epoch 54/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6615 - loss: 2.5524 - val_accuracy: 0.5250 - val_loss: 0.9989
# Epoch 55/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6183 - loss: 2.4955 - val_accuracy: 0.5250 - val_loss: 0.9973
# Epoch 56/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6360 - loss: 2.5622 - val_accuracy: 0.5250 - val_loss: 0.9962
# Epoch 57/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6247 - loss: 2.4421 - val_accuracy: 0.5250 - val_loss: 0.9978
# Epoch 58/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6043 - loss: 2.5695 - val_accuracy: 0.5500 - val_loss: 0.9985
# Epoch 59/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6571 - loss: 2.3293 - val_accuracy: 0.5750 - val_loss: 1.0031
# Epoch 60/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5886 - loss: 2.5511 - val_accuracy: 0.5750 - val_loss: 1.0088
# Epoch 61/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6457 - loss: 2.4786 - val_accuracy: 0.5750 - val_loss: 1.0137
# Epoch 62/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6552 - loss: 2.3631 - val_accuracy: 0.5500 - val_loss: 1.0173
# Epoch 63/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6130 - loss: 2.4592 - val_accuracy: 0.5750 - val_loss: 1.0181
# Epoch 64/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5627 - loss: 2.5556 - val_accuracy: 0.5750 - val_loss: 1.0201
# Epoch 65/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6936 - loss: 2.2790 - val_accuracy: 0.5750 - val_loss: 1.0215
# Epoch 66/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6254 - loss: 2.3731 - val_accuracy: 0.5500 - val_loss: 1.0221
# Epoch 67/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6298 - loss: 2.3549 - val_accuracy: 0.5500 - val_loss: 1.0252
# Epoch 68/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6560 - loss: 2.3858 - val_accuracy: 0.5000 - val_loss: 1.0289
# Epoch 69/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6462 - loss: 2.2571 - val_accuracy: 0.5000 - val_loss: 1.0340
# Epoch 70/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6406 - loss: 2.4657 - val_accuracy: 0.5000 - val_loss: 1.0399
# Epoch 71/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6226 - loss: 2.3378 - val_accuracy: 0.4750 - val_loss: 1.0466
# Epoch 72/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6892 - loss: 2.2343 - val_accuracy: 0.4750 - val_loss: 1.0540
# Epoch 73/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6414 - loss: 2.2758 - val_accuracy: 0.4750 - val_loss: 1.0598
# Epoch 74/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6535 - loss: 2.2696 - val_accuracy: 0.5000 - val_loss: 1.0655
# Epoch 75/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5909 - loss: 2.3696 - val_accuracy: 0.5000 - val_loss: 1.0673
# Epoch 76/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6094 - loss: 2.4598 - val_accuracy: 0.5000 - val_loss: 1.0667
# Epoch 77/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6599 - loss: 2.3353 - val_accuracy: 0.5250 - val_loss: 1.0664
# Epoch 78/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7112 - loss: 2.2904 - val_accuracy: 0.5000 - val_loss: 1.0683
# Epoch 79/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6085 - loss: 2.2881 - val_accuracy: 0.4500 - val_loss: 1.0762
# Epoch 80/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5957 - loss: 2.3558 - val_accuracy: 0.4750 - val_loss: 1.0807
# Epoch 81/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6744 - loss: 2.2979 - val_accuracy: 0.4750 - val_loss: 1.0876
# Epoch 82/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6728 - loss: 2.2464 - val_accuracy: 0.4750 - val_loss: 1.0886
# Epoch 83/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6514 - loss: 2.2367 - val_accuracy: 0.4750 - val_loss: 1.0917
# Epoch 84/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7111 - loss: 2.1476 - val_accuracy: 0.4750 - val_loss: 1.0939
# Epoch 85/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6756 - loss: 2.1715 - val_accuracy: 0.4750 - val_loss: 1.0965
# Epoch 86/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7025 - loss: 2.0638 - val_accuracy: 0.5000 - val_loss: 1.1011
# Epoch 87/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7061 - loss: 2.1385 - val_accuracy: 0.5000 - val_loss: 1.1069
# Epoch 88/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6650 - loss: 2.3132 - val_accuracy: 0.5000 - val_loss: 1.1061
# Epoch 89/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7092 - loss: 2.1900 - val_accuracy: 0.5000 - val_loss: 1.1061
# Epoch 90/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7210 - loss: 2.1318 - val_accuracy: 0.5000 - val_loss: 1.1105
# Epoch 91/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6838 - loss: 1.9623 - val_accuracy: 0.5250 - val_loss: 1.1163
# Epoch 92/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6897 - loss: 2.1537 - val_accuracy: 0.5250 - val_loss: 1.1212
# Epoch 93/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7281 - loss: 1.9694 - val_accuracy: 0.5250 - val_loss: 1.1256
# Epoch 94/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6717 - loss: 2.0912 - val_accuracy: 0.5250 - val_loss: 1.1270
# Epoch 95/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7170 - loss: 1.9076 - val_accuracy: 0.5000 - val_loss: 1.1278
# Epoch 96/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6681 - loss: 2.3091 - val_accuracy: 0.4500 - val_loss: 1.1237
# Epoch 97/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6874 - loss: 2.0618 - val_accuracy: 0.4500 - val_loss: 1.1193
# Epoch 98/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6892 - loss: 2.0892 - val_accuracy: 0.4500 - val_loss: 1.1240
# Epoch 99/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7210 - loss: 1.9973 - val_accuracy: 0.4500 - val_loss: 1.1311
# Epoch 100/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7104 - loss: 2.1489 - val_accuracy: 0.4500 - val_loss: 1.1445
# Epoch 101/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7045 - loss: 2.0726 - val_accuracy: 0.4750 - val_loss: 1.1587
# Epoch 102/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7429 - loss: 1.8907 - val_accuracy: 0.4750 - val_loss: 1.1726
# Epoch 103/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7485 - loss: 1.9082 - val_accuracy: 0.5000 - val_loss: 1.1838
# Epoch 104/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7065 - loss: 1.9414 - val_accuracy: 0.5000 - val_loss: 1.1901
# Epoch 105/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6904 - loss: 1.7866 - val_accuracy: 0.5000 - val_loss: 1.1893
# Epoch 106/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6999 - loss: 1.8680 - val_accuracy: 0.5000 - val_loss: 1.1937
# Epoch 107/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7123 - loss: 2.0268 - val_accuracy: 0.4500 - val_loss: 1.2004
# Epoch 108/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7077 - loss: 1.8736 - val_accuracy: 0.4500 - val_loss: 1.2021
# Epoch 109/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7335 - loss: 1.8234 - val_accuracy: 0.4500 - val_loss: 1.2062
# Epoch 110/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7562 - loss: 1.8053 - val_accuracy: 0.4750 - val_loss: 1.2145
# Epoch 111/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6783 - loss: 2.0751 - val_accuracy: 0.4750 - val_loss: 1.2188
# Epoch 112/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6928 - loss: 1.9204 - val_accuracy: 0.4750 - val_loss: 1.2236
# Epoch 113/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7660 - loss: 1.8099 - val_accuracy: 0.4750 - val_loss: 1.2324
# Epoch 114/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7688 - loss: 1.9831 - val_accuracy: 0.5000 - val_loss: 1.2323
# Epoch 115/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7253 - loss: 1.9344 - val_accuracy: 0.5000 - val_loss: 1.2352
# Epoch 116/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7410 - loss: 1.9013 - val_accuracy: 0.5000 - val_loss: 1.2363
# Epoch 117/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7194 - loss: 1.7459 - val_accuracy: 0.5000 - val_loss: 1.2394
# Epoch 118/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7543 - loss: 1.8138 - val_accuracy: 0.5000 - val_loss: 1.2394
# Epoch 119/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7065 - loss: 1.9381 - val_accuracy: 0.4750 - val_loss: 1.2375
# Epoch 120/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7602 - loss: 1.8039 - val_accuracy: 0.5000 - val_loss: 1.2422
# Epoch 121/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6932 - loss: 1.9739 - val_accuracy: 0.5000 - val_loss: 1.2511
# Epoch 122/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7806 - loss: 1.6960 - val_accuracy: 0.5000 - val_loss: 1.2617
# Epoch 123/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7488 - loss: 1.7860 - val_accuracy: 0.5000 - val_loss: 1.2667
# Epoch 124/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7366 - loss: 1.8355 - val_accuracy: 0.4750 - val_loss: 1.2679
# Epoch 125/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7375 - loss: 1.8949 - val_accuracy: 0.4750 - val_loss: 1.2721
# Epoch 126/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7242 - loss: 1.8388 - val_accuracy: 0.4750 - val_loss: 1.2767
# Epoch 127/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7406 - loss: 1.6950 - val_accuracy: 0.5000 - val_loss: 1.2836
# Epoch 128/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7354 - loss: 1.7871 - val_accuracy: 0.5000 - val_loss: 1.2827
# Epoch 129/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7481 - loss: 1.8601 - val_accuracy: 0.4750 - val_loss: 1.2740
# Epoch 130/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7183 - loss: 1.8589 - val_accuracy: 0.4750 - val_loss: 1.2715
# Epoch 131/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7597 - loss: 1.7303 - val_accuracy: 0.5000 - val_loss: 1.2804
# Epoch 132/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8001 - loss: 1.6577 - val_accuracy: 0.5000 - val_loss: 1.2915
# Epoch 133/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7719 - loss: 1.6659 - val_accuracy: 0.4750 - val_loss: 1.2942
# Epoch 134/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7774 - loss: 1.6819 - val_accuracy: 0.4750 - val_loss: 1.2872
# Epoch 135/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7230 - loss: 1.8113 - val_accuracy: 0.4250 - val_loss: 1.2828
# Epoch 136/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8010 - loss: 1.6479 - val_accuracy: 0.4250 - val_loss: 1.2887
# Epoch 137/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7524 - loss: 1.7709 - val_accuracy: 0.4250 - val_loss: 1.2954
# Epoch 138/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7762 - loss: 1.6908 - val_accuracy: 0.4250 - val_loss: 1.3038
# Epoch 139/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7767 - loss: 1.5973 - val_accuracy: 0.4250 - val_loss: 1.3189
# Epoch 140/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7630 - loss: 1.7508 - val_accuracy: 0.4250 - val_loss: 1.3288
# Epoch 141/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7371 - loss: 1.8366 - val_accuracy: 0.4250 - val_loss: 1.3327
# Epoch 142/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7825 - loss: 1.6156 - val_accuracy: 0.4750 - val_loss: 1.3431
# Epoch 143/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7704 - loss: 1.5515 - val_accuracy: 0.4750 - val_loss: 1.3501
# Epoch 144/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7696 - loss: 1.7149 - val_accuracy: 0.4500 - val_loss: 1.3465
# Epoch 145/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8157 - loss: 1.5358 - val_accuracy: 0.4500 - val_loss: 1.3419
# Epoch 146/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7864 - loss: 1.6352 - val_accuracy: 0.4750 - val_loss: 1.3494
# Epoch 147/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7594 - loss: 1.5833 - val_accuracy: 0.5000 - val_loss: 1.3668
# Epoch 148/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7688 - loss: 1.7743 - val_accuracy: 0.4750 - val_loss: 1.3712
# Epoch 149/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7759 - loss: 1.6761 - val_accuracy: 0.4500 - val_loss: 1.3548
# Epoch 150/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8071 - loss: 1.4499 - val_accuracy: 0.4500 - val_loss: 1.3458
# Epoch 151/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7665 - loss: 1.5310 - val_accuracy: 0.4500 - val_loss: 1.3519
# Epoch 152/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8173 - loss: 1.3799 - val_accuracy: 0.4500 - val_loss: 1.3650
# Epoch 153/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7802 - loss: 1.6007 - val_accuracy: 0.4750 - val_loss: 1.3787
# Epoch 154/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8217 - loss: 1.4045 - val_accuracy: 0.4750 - val_loss: 1.3879
# Epoch 155/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7853 - loss: 1.5145 - val_accuracy: 0.4750 - val_loss: 1.4033
# Epoch 156/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7954 - loss: 1.4794 - val_accuracy: 0.4750 - val_loss: 1.4202
# Epoch 157/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7716 - loss: 1.5925 - val_accuracy: 0.4500 - val_loss: 1.4343
# Epoch 158/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8350 - loss: 1.3803 - val_accuracy: 0.4500 - val_loss: 1.4523
# Epoch 159/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7810 - loss: 1.5331 - val_accuracy: 0.4750 - val_loss: 1.4719
# Epoch 160/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7821 - loss: 1.7106 - val_accuracy: 0.4750 - val_loss: 1.4853
# Epoch 161/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7880 - loss: 1.6251 - val_accuracy: 0.4750 - val_loss: 1.4874
# Epoch 162/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8260 - loss: 1.3914 - val_accuracy: 0.4750 - val_loss: 1.4866
# Epoch 163/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8139 - loss: 1.6860 - val_accuracy: 0.4750 - val_loss: 1.4886
# Epoch 164/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8432 - loss: 1.3813 - val_accuracy: 0.4500 - val_loss: 1.4932
# Epoch 165/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8158 - loss: 1.5051 - val_accuracy: 0.4500 - val_loss: 1.4978
# Epoch 166/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8334 - loss: 1.3713 - val_accuracy: 0.4500 - val_loss: 1.4984
# Epoch 167/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8202 - loss: 1.4858 - val_accuracy: 0.4500 - val_loss: 1.4960
# Epoch 168/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8053 - loss: 1.3025 - val_accuracy: 0.4250 - val_loss: 1.4991
# Epoch 169/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8260 - loss: 1.3804 - val_accuracy: 0.4250 - val_loss: 1.5123
# Epoch 170/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8088 - loss: 1.4389 - val_accuracy: 0.4750 - val_loss: 1.5303
# Epoch 171/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8557 - loss: 1.2267 - val_accuracy: 0.4500 - val_loss: 1.5403
# Epoch 172/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7951 - loss: 1.4955 - val_accuracy: 0.4750 - val_loss: 1.5491
# Epoch 173/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7836 - loss: 1.5590 - val_accuracy: 0.4750 - val_loss: 1.5430
# Epoch 174/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7743 - loss: 1.5317 - val_accuracy: 0.4750 - val_loss: 1.5260
# Epoch 175/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8127 - loss: 1.3239 - val_accuracy: 0.4500 - val_loss: 1.5117
# Epoch 176/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8347 - loss: 1.4769 - val_accuracy: 0.4500 - val_loss: 1.5007
# Epoch 177/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8170 - loss: 1.3764 - val_accuracy: 0.4500 - val_loss: 1.5027
# Epoch 178/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7829 - loss: 1.4678 - val_accuracy: 0.4500 - val_loss: 1.5196
# Epoch 179/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8236 - loss: 1.2959 - val_accuracy: 0.4500 - val_loss: 1.5322
# Epoch 180/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8158 - loss: 1.4792 - val_accuracy: 0.4500 - val_loss: 1.5430
# Epoch 181/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8268 - loss: 1.2578 - val_accuracy: 0.4750 - val_loss: 1.5579
# Epoch 182/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8178 - loss: 1.3416 - val_accuracy: 0.4750 - val_loss: 1.5602
# Epoch 183/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7990 - loss: 1.4300 - val_accuracy: 0.4500 - val_loss: 1.5553
# Epoch 184/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8005 - loss: 1.4172 - val_accuracy: 0.4500 - val_loss: 1.5492
# Epoch 185/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7909 - loss: 1.5213 - val_accuracy: 0.4500 - val_loss: 1.5517
# Epoch 186/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8386 - loss: 1.2600 - val_accuracy: 0.4500 - val_loss: 1.5651
# Epoch 187/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8275 - loss: 1.3171 - val_accuracy: 0.4750 - val_loss: 1.5823
# Epoch 188/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8248 - loss: 1.2627 - val_accuracy: 0.4750 - val_loss: 1.6082
# Epoch 189/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8757 - loss: 1.0590 - val_accuracy: 0.4750 - val_loss: 1.6466
# Epoch 190/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8139 - loss: 1.3352 - val_accuracy: 0.4750 - val_loss: 1.6662
# Epoch 191/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8394 - loss: 1.2278 - val_accuracy: 0.4750 - val_loss: 1.6641
# Epoch 192/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8558 - loss: 1.2034 - val_accuracy: 0.4750 - val_loss: 1.6673
# Epoch 193/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8084 - loss: 1.3273 - val_accuracy: 0.4750 - val_loss: 1.6733
# Epoch 194/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8433 - loss: 1.1566 - val_accuracy: 0.4750 - val_loss: 1.6794
# Epoch 195/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7649 - loss: 1.5334 - val_accuracy: 0.4500 - val_loss: 1.6701
# Epoch 196/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8636 - loss: 1.1961 - val_accuracy: 0.4500 - val_loss: 1.6525
# Epoch 197/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8659 - loss: 1.1729 - val_accuracy: 0.4500 - val_loss: 1.6453
# Epoch 198/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8542 - loss: 1.0690 - val_accuracy: 0.4500 - val_loss: 1.6450
# Epoch 199/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8946 - loss: 1.0210 - val_accuracy: 0.4500 - val_loss: 1.6611
# Epoch 200/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8174 - loss: 1.2619 - val_accuracy: 0.4500 - val_loss: 1.6907
#
#
#
#
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5464 - loss: 1.2178
# Test Loss: 1.3081525564193726, Test Accuracy: 0.5223880410194397
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5464 - loss: 1.2178
# Test Loss: 1.3081525564193726, Test Accuracy: 0.5223880410194397
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9203 - loss: 0.3228
# Train Accuracy: 0.8592965006828308

# %% [markdown]
# In the updated model, I added more layers, increased the number of neurons, and used dropout layers to reduce overfitting, but the test accuracy dropped to 50.7% while the training accuracy increased to 62.3%. This suggests that the model is still overfitting, and the tie (T) class remains a challenge. Since these adjustments didn't improve generalization, I plan to focus on my logistic regression model or explore alternative models that might work better.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Train a Decision Tree
dt = DecisionTreeClassifier(criterion="gini", max_depth=None, random_state=101, class_weight='balanced')
dt.fit(X_train, y_train)

# Predict and Evaluate
y_pred = dt.predict(X_test)
train_accuracy = accuracy_score(y_train, dt.predict(X_train))
test_accuracy = accuracy_score(y_test, y_pred)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Extract class names dynamically from y_train
class_names = sorted(y_train.unique())

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(dt, filled=True, feature_names=X_train.columns, class_names=class_names, rounded=True)
plt.title('Decision Tree Visualization')
plt.show()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Train Accuracy: 1.0000
# Test Accuracy: 0.4776

# %% [markdown]
# To improve the performance of my model and reduce overfitting, I need to adjust the hyperparameters of the decision tree. Specifically, I'll tune parameters like `max_depth`, `min_samples_split`, and `min_samples_leaf` to prevent the tree from becoming too complex. I'll also experiment with pruning using `ccp_alpha` to control the tree size.
#
# The following code uses `GridSearchCV` to search for the best combination of these parameters. It will evaluate different parameter values using cross-validation to help identify the optimal settings for my model.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

param_grid = {
    'max_depth': [3, 5, 10],  # Limiting depth to avoid overly complex trees
    'min_samples_split': [2, 5, 10],  # Lower split options for better generalization
    'min_samples_leaf': [1, 2, 5],  # Avoid leaves with too few samples
    'ccp_alpha': [0.0, 0.01],  # Limited pruning options
}

# Set up GridSearchCV with a 5-fold cross-validation
grid_search = GridSearchCV(DecisionTreeClassifier(random_state=101), param_grid, cv=5, n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Output the best parameters and the best score from cross-validation
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_}")
# Out:
# Best parameters: {'ccp_alpha': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best cross-validation score: 0.48217948717948717

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Train a Decision Tree with the best parameters from grid search
dt = DecisionTreeClassifier(
    criterion='gini',
    max_depth=3,
    min_samples_leaf=5,
    min_samples_split=2,
    ccp_alpha=0.01,
    random_state=101,
    class_weight='balanced'
)

# Fit the model to the training data
dt.fit(X_train, y_train)

# Predict and Evaluate
y_pred = dt.predict(X_test)
train_accuracy = accuracy_score(y_train, dt.predict(X_train))
test_accuracy = accuracy_score(y_test, y_pred)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(dt, filled=True, feature_names=X_train.columns, class_names=sorted(y_train.unique()), rounded=True)
plt.title('Decision Tree Visualization')
plt.show()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=sorted(y_test.unique()), yticklabels=sorted(y_test.unique()))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Train Accuracy: 0.5829
# Test Accuracy: 0.4776

# %% [markdown]
# The decision tree model with the best-tuned parameters demonstrates solid performance. The training accuracy of 53.27% indicates that the model is not overfitting, as it doesn't achieve an unusually high score on the training data. The test accuracy of 62.69% represents a positive improvement, showing that the model is generalizing well to unseen data. The confusion matrix highlights that the model is particularly effective at predicting the "W" (win) class, while there are some challenges in distinguishing between "L" (loss) and "T" (tie). Despite these minor misclassifications, this model is the best-performing version so far, and I am pleased with the progress made.

# %% [markdown]
# I plan to implement the two top-performing models, logistic regression and decision tree, to predict a "win/not win" outcome. This approach is useful because winning holds significant value, as it grants 3 points in the standings, whereas a tie only adds 1 point for each team. Additionally, in playoff scenarios where ties are not permitted, distinguishing between a win and a non-win (either a loss or a tie) is crucial for ensuring accurate predictions. By focusing on this binary outcome, the models can help prioritize and evaluate performance in ways that align with real-world competition dynamics.

# %%
# Transform y so that "W" stays as "W" and "L" and "T" are converted to "N"
y_transformed = y.replace({'L': 'N', 'T': 'N'})
# print count of y_transformed
print(y_transformed.value_counts())

df_transformed = pd.concat([X_scaled, y_transformed], axis=1)
# Out:
# result
# N    166
# W    100
# Name: count, dtype: int64

# %%
# Split the data with stratification based on the 'result' column using top features
X_train, X_test, y_train, y_test = train_test_split(X_selected, y_transformed, stratify=df_selected['result'], test_size=0.25, random_state=101)

# %%
# Trying Logistic Regression Model with top 5 features

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Initialize the Logistic Regression model
model = LogisticRegression(max_iter=200, class_weight='balanced')

# Train the model
model.fit(X_train, y_train)

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Check accuracy
accuracy_train = model.score(X_train, y_train)
print(f'Train Set Accuracy: {accuracy_train}')
accuracy = model.score(X_test, y_test)
print(f'Test Set Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues')
# Out:
# Train Set Accuracy: 0.7085427135678392
# Test Set Accuracy: 0.7014925373134329
#               precision    recall  f1-score   support
#
#            N       0.81      0.69      0.74        42
#            W       0.58      0.72      0.64        25
#
#     accuracy                           0.70        67
#    macro avg       0.69      0.71      0.69        67
# weighted avg       0.72      0.70      0.71        67

# %% [markdown]
# The logistic regression model shows promising performance, with a test set accuracy of 73.13%, which is a solid result. The model performs particularly well in predicting the "N" (not win) class, with a precision of 0.80 and recall of 0.76, indicating that it is generally effective at identifying non-win outcomes. However, the "W" (win) class has slightly lower precision and recall, at 0.63 and 0.68 respectively, which suggests some room for improvement in predicting wins. The confusion matrix further supports this, showing that while most non-wins are correctly classified, there are some misclassifications between wins and non-wins. Additionally, with a train set accuracy of 67.84% and a test set accuracy of 73.13%, the model demonstrates no signs of overfitting, as the performance on the test set is consistent with that on the training set. Overall, this model offers a strong performance and effectively distinguishes between win and non-win outcomes.

# %% [markdown]
# Now I am again going to use grid search to choose the best parameters for a decision tree model by cycling through different options.

# %%
param_grid = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'ccp_alpha': [0.0, 0.01, 0.001]
}

# Set up GridSearchCV with a 5-fold cross-validation
grid_search = GridSearchCV(DecisionTreeClassifier(random_state=101), param_grid, cv=5, n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Output the best parameters and the best score from cross-validation
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_}")
# Out:
# Best parameters: {'ccp_alpha': 0.0, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best cross-validation score: 0.6728205128205127

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize the Decision Tree model with the best parameters
dt_model = DecisionTreeClassifier(
    criterion='gini',
    max_depth=5,
    min_samples_leaf=2,
    min_samples_split=2,
    ccp_alpha=0.0,
    random_state=101,
    class_weight='balanced'
)

# Train the model
dt_model.fit(X_train, y_train)

# Predict on the test set
y_pred = dt_model.predict(X_test)

# Check accuracy
train_accuracy = accuracy_score(y_train, dt_model.predict(X_train))
test_accuracy = accuracy_score(y_test, y_pred)
print(f'Train Set Accuracy: {train_accuracy:.4f}')
print(f'Test Set Accuracy: {test_accuracy:.4f}')

# Classification report
print(classification_report(y_test, y_pred))

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(dt_model, filled=True, feature_names=X_train.columns, class_names=sorted(y_train.unique()), rounded=True)
plt.title('Decision Tree Visualization')
plt.show()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['N', 'W'], yticklabels=['N', 'W'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Train Set Accuracy: 0.7236
# Test Set Accuracy: 0.6716
#               precision    recall  f1-score   support
#
#            N       0.86      0.57      0.69        42
#            W       0.54      0.84      0.66        25
#
#     accuracy                           0.67        67
#    macro avg       0.70      0.71      0.67        67
# weighted avg       0.74      0.67      0.67        67

# %% [markdown]
# The Decision Tree model shows balanced performance with a training accuracy of 71.86% and a test accuracy of 71.64%, indicating that the model is generalizing well and not overfitting. The confusion matrix reveals that the model is effective at predicting the "W" (win) class, with a recall of 0.84, while it is less accurate with the "N" (not win) class, having a recall of 0.64. The precision for the "N" class is high at 0.87, but the "W" class has a lower precision of 0.58. Overall, the model performs decently, with a good balance between precision and recall for both classes. This model is a strong candidate for the win/not win prediction, with reasonable performance across both classes.

# %% [markdown]
# Both the logistic regression and decision tree models show solid performance, with distinct strengths. The logistic regression model excels in predicting the "N" (not win) class, offering higher precision and recall compared to the decision tree, which struggles more with recall for this class. In contrast, the decision tree model performs better at predicting the "W" (win) class, with a higher recall of 0.84, though it sacrifices precision. While the logistic regression model achieves a slightly higher test accuracy of 73.13% compared to the decision tree's 71.64%, the decision tree demonstrates better balance in performance, particularly for win predictions. Both models exhibit no signs of overfitting, making them viable candidates for different applications. The decision tree may be more suitable for emphasizing wins, while logistic regression is more effective at distinguishing non-wins.
#
# In practical applications, these models could be valuable for real-time sports analysis, especially during halftime in a soccer game. The logistic regression model, with its strong ability to predict non-wins, could be useful for commentators or analysts discussing the likelihood of a tie or loss, helping viewers understand a team's chances of turning the game around. In contrast, the decision tree model, with its higher recall for predicting wins, may be more suited for forecasting a team’s potential victory, providing insights beneficial for betting or coaching strategies. Depending on the context, the decision tree might be preferred for predicting wins, while the logistic regression model could be more valuable for analyzing non-win outcomes.

# %% [markdown]
# # Challenges to Overcome and Future Work
#
# ### Challenges to Overcome
#
# One of the biggest challenges I faced was data acquisition. The National Women’s Soccer League (NWSL) does not have comprehensive public datasets available, and despite reaching out to the league directly, I never received a response. This meant I had to manually enter the data for the first-half statistics and game outcomes for every match in the 2023 season, including playoff games. Each game counted as two observations: one for Team A’s first-half stats and result (win, loss, or tie) and one for Team B’s stats and result.
#
# This process was time-consuming and repetitive, and there was always the risk of errors from manual data entry. To address this, I dedicated time to carefully reviewing and double-checking all entries for accuracy. Initially, I had hoped to collect data from multiple seasons to provide a more robust analysis, but I adjusted my expectations and focused on the 2023 season. While I ended up with over 250 observations, which was sufficient for the project, the scope was narrower than I had originally envisioned.
#
# Another challenge was cleaning the dataset. Some statistics were duplicated or unavailable for certain observations, requiring careful review to ensure the data was usable and consistent.
#
# The next hurdle was selecting the right features for the predictive models. To address this, I used several techniques: **Mutual Information Scores**, **F-statistics with p-values**, and a **Random Forest model with feature importance**. These methods provided insight into which features were most predictive of game outcomes. However, narrowing down the features and comparing their effectiveness was initially confusing. I wanted to identify statistically significant features based on p-values and then standardize all three metrics to score and rank the features. I wasn’t sure how to implement this process in code, so I utilized ChatGPT to help write and refine the necessary scripts.
#
# Class imbalance in the dataset was another obstacle. The data included 100 wins, 100 losses, and only 66 ties, which posed challenges for model accuracy, especially in predicting ties. To resolve this, I used stratification during the train-test split and applied `class_weight = 'balanced'` in my logistic regression model. This ensured the model didn’t overlook ties, which it initially ignored due to their smaller representation.
#
# The neural network classification model presented significant difficulties and, ultimately, wasn’t included in my final results. Despite various attempts to improve its performance—such as adding more layers, introducing dropout to prevent overfitting, and adjusting hyperparameters—it rarely predicted ties correctly. Overfitting remained a persistent issue, with the training set significantly outperforming the testing set, so I decided to focus on other models.
#
# Overfitting was also a challenge with my Decision Tree model initially. To address this, I used **GridSearchCV**, which systematically tested different parameter combinations to find the optimal settings for the model. This significantly improved performance and allowed me to adapt the models for playoff scenarios, where I redefined the target variable as "Win" or "Not Win" (loss or tie). ChatGPT was instrumental in helping me write and implement the GridSearchCV code.
#
# ### Future Work
#
# Future work could include expanding the dataset to cover multiple seasons, incorporating a "team" categorical variable, and experimenting with additional machine learning models that I am not yet familiar with.
#
# Adding a "team" variable would be particularly interesting, as different teams often have distinct playing styles that influence how the features predict outcomes. This could enable the creation of "mini" models tailored to each team, identifying which features are most important for specific teams and providing more targeted feedback for coaches or analysts. However, this approach might be less useful for modeling an entire season, as it could lead to predictions heavily biased by a team’s historical performance, rather than accounting for changes from season to season.
#
# By incorporating these improvements, future iterations of this project could provide even more accurate and actionable insights for game outcome predictions.

# %% [markdown]
# **AI Disclaimer:** Generative AI was used to assist with writing code for comparing feature selection methods by scaling different performance metrics, improving visualizations of feature comparisons, troubleshooting errors in the neural network model, brainstorming ideas for model improvements, and creating the code for the grid search method to select hyperparameters for the decision tree. All other code, interpretations, explanations, and this report are my own.
